# %%
#Library import
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
import collections

# %%
#File Import
G = nx.read_edgelist("protein.edgelist.txt")

# %%
#Zip deg cnt
degree_sequence = sorted([d for n, d in G.degree()], reverse=True)
degreeCount = collections.Counter(degree_sequence)
deg, cnt = zip(*degreeCount.items())

# %%
plt.bar(deg, cnt, width = 0.8, color = 'b') #1 Como es el grado de ditribución
# Out:
# <BarContainer object of 34 artists>

# %%
list(G) #List of nodes

# %%
nx.node_connectivity(G) # 2 NODE CONECTIVITY
# Out:
# 0

# %%
nx.node_connectivity(G,s='4',t='1228') #Para que se desconecte de los nodos 4,1228
# Out:
# 1

# %%
#Find cliques where n>3
c = zip(*nx.find_cliques(G))
from pandas import DataFrame
data = list(nx.find_cliques(G))
clika = DataFrame.from_records(data)
clika.dropna(thresh=3) #Tabla de cliques > 3
# Out:
#          0     1     2     3     4
# 17    1714   528   584  None  None
# 20    1714  1888  1651  None  None
# 28     513   711   742  None  None
# 29     513   711   580  None  None
# 33    1488   798  1176  None  None
# 44    1488   845  1196  None  None
# 45    1488   845  1420  None  None
# 46    1488   845   252  None  None
# 47    1488   845  1750  None  None
# 53    1432  1522   261  None  None
# 65    1601  2015   806  None  None
# 96     309   515  1883  None  None
# 119    952  1017   512  None  None
# 124    773   515  1883   908  None
# 138   1886  1130  1500  None  None
# 155    621  1406   475  None  None
# 156    621  1406  1059  None  None
# 157    621  1406  1624  None  None
# 226   1618   315  1315  None  None
# 227   1618   315   905  None  None
# 232   1524  1911   140  None  None
# 249   1796  1400  1401  None  None
# 250   1796  1400   806  None  None
# 262   1545   254  1392  None  None
# 281    436   437   174  None  None
# 289    338  1226   803   693  None
# ...

# %%
#Figure
plt.figure(figsize=(20,20))
#Layout
pos=nx.kamada_kawai_layout(G)
#Drawing in plt using nx
nx.draw_networkx_labels(G, pos = pos, font_size=11, font_family='sans-serif', font_color='black')
nx.draw_networkx_edges(G,pos=pos, alpha=0.005, width=0.1)
nx.draw(G, pos = pos, with_labels = False, node_size =200)
plt.axis('off')
plt.tight_layout();
